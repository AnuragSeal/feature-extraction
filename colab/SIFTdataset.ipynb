# %%
# !pip install opencv-contrib-python==4.4.0.44
# Out:
# Requirement already satisfied: opencv-contrib-python==4.4.0.44 in /usr/local/lib/python3.7/dist-packages (4.4.0.44)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-contrib-python==4.4.0.44) (1.19.5)

# %%
# !pip install opencv-python==4.4.0.44
# Out:
# Collecting opencv-python==4.4.0.44
#   Downloading https://files.pythonhosted.org/packages/01/d0/23b56d1c4a301d57ffa5d9aa0df9894053e43e439c9a710c8986ad7b3999/opencv_python-4.4.0.44-cp37-cp37m-manylinux2014_x86_64.whl (49.5MB)
#      |████████████████████████████████| 49.5MB 63kB/s
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python==4.4.0.44) (1.19.5)
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: opencv-python
#   Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
# Successfully installed opencv-python-4.4.0.44

# %%
import cv2 as cv2
sift = cv2.SIFT_create ()

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-45cd6f21-7647-4728-8fe9-e39a81deebf5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-45cd6f21-7647-4728-8fe9-e39a81deebf5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cloudy-left.mp4 to cloudy-left.mp4
# Saving cloudy-right.mp4 to cloudy-right.mp4
# Saving foggy-left.mp4 to foggy-left.mp4
# Saving foggy-right.mp4 to foggy-right.mp4
# Saving rainy-left.mp4 to rainy-left.mp4
# Saving rainy-right.mp4 to rainy-right.mp4
# Saving sunny-left.mp4 to sunny-left.mp4
# Saving sunny-right.mp4 to sunny-right.mp4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#visualise the uploaded video files
from IPython.display import HTML
from base64 import b64encode

def play(filename):
    html = ''
    video = open(filename,'rb').read()
    src = 'data:video/mp4;base64,' + b64encode(video).decode()
    html += '<video width=1000 controls autoplay loop><source src="%s" type="video/mp4"></video>' % src 
    return HTML(html)

play('cloudy-left.mp4')

# %%
import cv2
import numpy as np
import time

# %%
start_time = time.time()
cap_l = cv2.VideoCapture('/content/sunny-left.mp4')
cap_r = cv2.VideoCapture('/content/sunny-right.mp4')
sift = cv2.SIFT_create ()
bf = cv2.BFMatcher(cv2.NORM_L2, crossCheck=True)


kp_l_list = []
kp_l_vs_time_list = []
kp_r_list = []
kp_r_vs_time_list = []
matches_list = []
matches_vs_time_list = []
fps_list = []
fps_vs_time_list = []



while True:
    _l,frame_l = cap_l.read()
    _r,frame_r = cap_r.read()
    
    if _l is True and _r is True:
      
      start_time_fps = time.time()

      frame_l = cv2.resize(frame_l,None,fx=0.4,fy=0.4,interpolation=cv2.INTER_AREA)
      frame_r = cv2.resize(frame_r,None,fx=0.4,fy=0.4,interpolation=cv2.INTER_AREA)

      gray_l= cv2.cvtColor(frame_l, cv2.COLOR_BGR2GRAY)
      gray_r= cv2.cvtColor(frame_r, cv2.COLOR_BGR2GRAY)

      kp_l,des_l = sift.detectAndCompute(gray_l,None)
      kp_r,des_r = sift.detectAndCompute(gray_r,None)


      if des_l is not None and des_r is not None:

        matches = bf.match(des_l,des_r)
        matches_list.append(len(matches))
        matches_vs_time_list.append([time.time() - start_time,len(matches)])

        kp_l_list.append(len(kp_l))
        kp_l_vs_time_list.append([time.time() - start_time,len(kp_l)])
        kp_r_list.append(len(kp_r))
        kp_r_vs_time_list.append([time.time() - start_time,len(kp_r)])


        fps = 1/(time.time()-start_time_fps)
        fps = int(fps)
        fps_list.append(fps)
        fps_vs_time_list.append([time.time() - start_time,fps])
      
      else:
        pass

    else:
      print("Avg. Keypoints Left:",sum(kp_l_list)/len(kp_l_list))
      np.savetxt("sift_sunny_kp_left_vs_time.csv", kp_l_vs_time_list,delimiter =", ",fmt ='% s')

      print("Avg. Keypoints Right:",sum(kp_r_list)/len(kp_r_list))
      np.savetxt("sift_sunny_kp_right_vs_time.csv", kp_r_vs_time_list,delimiter =", ",fmt ='% s')

      print("Avg. Matches:",sum(matches_list)/len(matches_list))
      np.savetxt("sift_sunny_matches_vs_time.csv", matches_vs_time_list,delimiter =", ",fmt ='% s')

      print("Avg. fps:",sum(fps_list)/len(fps_list))
      np.savetxt("sift_sunny_fps_vs_time.csv", fps_vs_time_list,delimiter =", ",fmt ='% s')
      
      t = time.time() - start_time
      print("Execution Time:",t,"secs")
      print("Finished!")
      
      break
# Out:
# Avg. Keypoints Left: 345.62
# Avg. Keypoints Right: 355.228
# Avg. Matches: 186.818
# Avg. fps: 10.694
# Execution Time: 47.23786997795105 secs
# Finished!

# %%
start_time = time.time()
cap_l = cv2.VideoCapture('/content/cloudy-left.mp4')
cap_r = cv2.VideoCapture('/content/cloudy-right.mp4')
sift = cv2.SIFT_create ()
orb = cv2.ORB_create()
bf = cv2.BFMatcher(cv2.NORM_L2, crossCheck=True)


kp_l_list = []
kp_l_vs_time_list = []
kp_r_list = []
kp_r_vs_time_list = []
matches_list = []
matches_vs_time_list = []
fps_list = []
fps_vs_time_list = []



while True:
    _l,frame_l = cap_l.read()
    _r,frame_r = cap_r.read()
    
    if _l is True and _r is True:
      
      start_time_fps = time.time()

      frame_l = cv2.resize(frame_l,None,fx=0.4,fy=0.4,interpolation=cv2.INTER_AREA)
      frame_r = cv2.resize(frame_r,None,fx=0.4,fy=0.4,interpolation=cv2.INTER_AREA)

      gray_l= cv2.cvtColor(frame_l, cv2.COLOR_BGR2GRAY)
      gray_r= cv2.cvtColor(frame_r, cv2.COLOR_BGR2GRAY)

      kp_l,des_l = sift.detectAndCompute(gray_l,None)
      kp_r,des_r = sift.detectAndCompute(gray_r,None)

      if des_l is not None and des_r is not None:

        matches = bf.match(des_l,des_r)
        matches_list.append(len(matches))
        matches_vs_time_list.append([time.time() - start_time,len(matches)])

        kp_l_list.append(len(kp_l))
        kp_l_vs_time_list.append([time.time() - start_time,len(kp_l)])
        kp_r_list.append(len(kp_r))
        kp_r_vs_time_list.append([time.time() - start_time,len(kp_r)])


        fps = 1/(time.time()-start_time_fps)
        fps = int(fps)
        fps_list.append(fps)
        fps_vs_time_list.append([time.time() - start_time,fps])
      
      else:
        pass

    else:
      print("Avg. Keypoints Left:",sum(kp_l_list)/len(kp_l_list))
      np.savetxt("sift_cloudy_kp_left_vs_time.csv", kp_l_vs_time_list,delimiter =", ",fmt ='% s')

      print("Avg. Keypoints Right:",sum(kp_r_list)/len(kp_r_list))
      np.savetxt("sift_cloudy_kp_right_vs_time.csv", kp_r_vs_time_list,delimiter =", ",fmt ='% s')

      print("Avg. Matches:",sum(matches_list)/len(matches_list))
      np.savetxt("sift_cloudy_matches_vs_time.csv", matches_vs_time_list,delimiter =", ",fmt ='% s')

      print("Avg. fps:",sum(fps_list)/len(fps_list))
      np.savetxt("sift_cloudy_fps_vs_time.csv", fps_vs_time_list,delimiter =", ",fmt ='% s')
      
      t = time.time() - start_time
      print("Execution Time:",t,"secs")
      print("Finished!")
      
      break
# Out:
# Avg. Keypoints Left: 278.942
# Avg. Keypoints Right: 281.104
# Avg. Matches: 153.228
# Avg. fps: 12.22
# Execution Time: 42.77322173118591 secs
# Finished!

# %%
start_time = time.time()
cap_l = cv2.VideoCapture('/content/foggy-left.mp4')
cap_r = cv2.VideoCapture('/content/foggy-right.mp4')
sift = cv2.SIFT_create ()
orb = cv2.ORB_create()
bf = cv2.BFMatcher(cv2.NORM_L2, crossCheck=True)


kp_l_list = []
kp_l_vs_time_list = []
kp_r_list = []
kp_r_vs_time_list = []
matches_list = []
matches_vs_time_list = []
fps_list = []
fps_vs_time_list = []



while True:
    _l,frame_l = cap_l.read()
    _r,frame_r = cap_r.read()
    
    if _l is True and _r is True:
      
      start_time_fps = time.time()

      frame_l = cv2.resize(frame_l,None,fx=0.4,fy=0.4,interpolation=cv2.INTER_AREA)
      frame_r = cv2.resize(frame_r,None,fx=0.4,fy=0.4,interpolation=cv2.INTER_AREA)

      gray_l= cv2.cvtColor(frame_l, cv2.COLOR_BGR2GRAY)
      gray_r= cv2.cvtColor(frame_r, cv2.COLOR_BGR2GRAY)

      kp_l,des_l = sift.detectAndCompute(gray_l,None)
      kp_r,des_r = sift.detectAndCompute(gray_r,None)

      if des_l is not None and des_r is not None:

        matches = bf.match(des_l,des_r)
        matches_list.append(len(matches))
        matches_vs_time_list.append([time.time() - start_time,len(matches)])

        kp_l_list.append(len(kp_l))
        kp_l_vs_time_list.append([time.time() - start_time,len(kp_l)])
        kp_r_list.append(len(kp_r))
        kp_r_vs_time_list.append([time.time() - start_time,len(kp_r)])


        fps = 1/(time.time()-start_time_fps)
        fps = int(fps)
        fps_list.append(fps)
        fps_vs_time_list.append([time.time() - start_time,fps])
      
      else:
        pass

    else:
      print("Avg. Keypoints Left:",sum(kp_l_list)/len(kp_l_list))
      np.savetxt("sift_foggy_kp_left_vs_time.csv", kp_l_vs_time_list,delimiter =", ",fmt ='% s')

      print("Avg. Keypoints Right:",sum(kp_r_list)/len(kp_r_list))
      np.savetxt("sift_foggy_kp_right_vs_time.csv", kp_r_vs_time_list,delimiter =", ",fmt ='% s')

      print("Avg. Matches:",sum(matches_list)/len(matches_list))
      np.savetxt("sift_foggy_matches_vs_time.csv", matches_vs_time_list,delimiter =", ",fmt ='% s')

      print("Avg. fps:",sum(fps_list)/len(fps_list))
      np.savetxt("sift_foggy_fps_vs_time.csv", fps_vs_time_list,delimiter =", ",fmt ='% s')
      
      t = time.time() - start_time
      print("Execution Time:",t,"secs")
      print("Finished!")
      
      break
# Out:
# Avg. Keypoints Left: 155.736
# Avg. Keypoints Right: 165.546
# Avg. Matches: 93.902
# Avg. fps: 14.166
# Execution Time: 36.23314309120178 secs
# Finished!

# %%
start_time = time.time()
cap_l = cv2.VideoCapture('/content/rainy-left.mp4')
cap_r = cv2.VideoCapture('/content/rainy-right.mp4')
sift = cv2.SIFT_create ()
orb = cv2.ORB_create()
bf = cv2.BFMatcher(cv2.NORM_L2, crossCheck=True)


kp_l_list = []
kp_l_vs_time_list = []
kp_r_list = []
kp_r_vs_time_list = []
matches_list = []
matches_vs_time_list = []
fps_list = []
fps_vs_time_list = []



while True:
    _l,frame_l = cap_l.read()
    _r,frame_r = cap_r.read()
    
    if _l is True and _r is True:
      
      start_time_fps = time.time()

      frame_l = cv2.resize(frame_l,None,fx=0.4,fy=0.4,interpolation=cv2.INTER_AREA)
      frame_r = cv2.resize(frame_r,None,fx=0.4,fy=0.4,interpolation=cv2.INTER_AREA)

      gray_l= cv2.cvtColor(frame_l, cv2.COLOR_BGR2GRAY)
      gray_r= cv2.cvtColor(frame_r, cv2.COLOR_BGR2GRAY)

      kp_l,des_l = sift.detectAndCompute(gray_l,None)
      kp_r,des_r = sift.detectAndCompute(gray_r,None)

      if des_l is not None and des_r is not None:

        matches = bf.match(des_l,des_r)
        matches_list.append(len(matches))
        matches_vs_time_list.append([time.time() - start_time,len(matches)])

        kp_l_list.append(len(kp_l))
        kp_l_vs_time_list.append([time.time() - start_time,len(kp_l)])
        kp_r_list.append(len(kp_r))
        kp_r_vs_time_list.append([time.time() - start_time,len(kp_r)])


        fps = 1/(time.time()-start_time_fps)
        fps = int(fps)
        fps_list.append(fps)
        fps_vs_time_list.append([time.time() - start_time,fps])
      
      else:
        pass

    else:
      print("Avg. Keypoints Left:",sum(kp_l_list)/len(kp_l_list))
      np.savetxt("sift_rainy_kp_left_vs_time.csv", kp_l_vs_time_list,delimiter =", ",fmt ='% s')

      print("Avg. Keypoints Right:",sum(kp_r_list)/len(kp_r_list))
      np.savetxt("sift_rainy_kp_right_vs_time.csv", kp_r_vs_time_list,delimiter =", ",fmt ='% s')

      print("Avg. Matches:",sum(matches_list)/len(matches_list))
      np.savetxt("sift_rainy_matches_vs_time.csv", matches_vs_time_list,delimiter =", ",fmt ='% s')

      print("Avg. fps:",sum(fps_list)/len(fps_list))
      np.savetxt("sift_rainy_fps_vs_time.csv", fps_vs_time_list,delimiter =", ",fmt ='% s')
      
      t = time.time() - start_time
      print("Execution Time:",t,"secs")
      print("Finished!")
      
      break
# Out:
# Avg. Keypoints Left: 156.966
# Avg. Keypoints Right: 174.146
# Avg. Matches: 88.03
# Avg. fps: 18.266
# Execution Time: 29.701027154922485 secs
# Finished!
